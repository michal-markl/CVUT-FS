# %% [markdown]
# <body>
#     <div style="float:left; width:30%">
#         <img src="Images\CTU_logo_banner.png" width="360" align="left"/>
#     </div>
#     <div style="float:right; width:0%">
#         <img src="Images\PS3.png" width="200" align="left"/>
#     </div>
# </body>

# %% [markdown]
# <div>
#     <b style="color:#2A80EE">• This 📘 notebook serves core file for accessing notes.</b><br>
#     <b style="color:#4E6580">• Author: Michal MARKL</b><br><br>
# </div>
# <hr>

# %% [markdown]
# <link rel="stylesheet" href="cvut_vscode_stylesheet.css">
# <body>
#   <div style="float:left; width: 600px">
#     <table style="border:solid 2px;">
#       <tr>
#         <th colspan="4" style="border:solid 2px;">SUBJECTS</th>
#       </tr>
#       <tr>
#         <th></th>
#         <th>SEMESTER</th>
#         <th>NAME</th>
#         <th>CODE</th>
#       </tr>
#       <tr>
#         <td>📘</td>
#         <td style="text-align:center">2.</td>
#         <td><a href="Subjects\ZTE_II.ipynb" style="color:#2A80EE"><b>ZÁKLADY TECHNOLOGIE I</b></a></td>
#         <td><a href="https://new.kos.cvut.cz/course-syllabus/2333041">2333041</a></td>
#       </tr>
#       <tr>
#         <td>📘</td>
#         <td style="text-align:center" rowspan="8">3.</td>
#         <td><a href="Subjects\MA_III.ipynb" style="color:#2A80EE"><b>MATEMATIKA III</b></a></td>
#         <td><a href="https://new.kos.cvut.cz/course-syllabus/2011093">2011093</a></td>
#       </tr>
#       <tr>
#         <td>📘</td>
#         <td><a href="Subjects\ME_TEK.ipynb" style="color:#2A80EE"><b>MECHANIKA TEKUTIN</b></a></td>
#         <td><a href="https://new.kos.cvut.cz/course-syllabus/2121502">2121502</a></td>
#       </tr>
#       <tr>
#         <td>📘</td>
#         <td><a href="Subjects\ME_I.ipynb" style="color:#2A80EE"><b>MECHANIKA I</b></a></td>
#         <td><a href="https://new.kos.cvut.cz/course-syllabus/2311101">2311101</a></td>
#       </tr>
#       <tr>
#         <td>📘</td>
#         <td><a href="Subjects\CHEM.ipynb" style="color:#2A80EE"><b>CHEMIE</b></a></td>
#         <td><a href="https://new.kos.cvut.cz/course-syllabus/2182019">2182019</a></td>
#       </tr>
#       <tr>
#         <td>📘</td>
#         <td><a href="Subjects\ME_TEK.ipynb" style="color:#2A80EE"><b>NAUKA O MATERIÁLU II</b></a></td>
#         <td><a href="https://new.kos.cvut.cz/course-syllabus/2321039">2321039</a></td>
#       </tr>
#       <tr>
#         <td>📘</td>
#         <td><a href="Subjects\ME_TEK.ipynb" style="color:#2A80EE"><b>ZÁKLADY ALGORITMIZACE A PROGRAMOVÁNÍ</b></a></td>
#         <td><a href="https://new.kos.cvut.cz/course-syllabus/2012036">2012036</a></td>
#       </tr>
#       <tr>
#         <td>📘</td>
#         <td><a href="Subjects\TE_I.ipynb" style="color:#2A80EE"><b>TECHNOLOGIE I</b></a></td>
#         <td><a href="https://new.kos.cvut.cz/course-syllabus/2331093">2331093</a></td>
#       </tr>
#       <tr>
#         <td>📘</td>
#         <td><a href="Subjects\SK_III.ipynb" style="color:#2A80EE"><b>STROJÍRENSKÉ KONSTRUOVÁNÍ III</b></a></td>
#         <td><a href="https://new.kos.cvut.cz/course-syllabus/2133013">2133013</a></td>
#       </tr>
#     </table>
#   </div>
#
#   <div style="float:left; width:320px">
#     <table style="border:solid 3px;">
#       <tr style="background-color:transparent">
#         <th colspan="4" style="border:solid 3px;">TASKS</th>
#       </tr>
#       <tr style="text-align:left">
#         <th>
#           • Výpisky ze Základů technologií I
#           <br>
#           •
#         </th>
#       </tr>
#     </table>
#   </div>
#
# </body>
